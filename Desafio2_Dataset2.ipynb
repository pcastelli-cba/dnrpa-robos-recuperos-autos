# %% [markdown]
# <a href="https://colab.research.google.com/github/pcastelli-cba/dnrpa-robos-recuperos-autos/blob/main/Desafio2_Dataset2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #DATASET ROBOS RECUPEROS DE AUTOS

# %% [markdown]
# #Leyendo archivos para generar dataset

# %% [markdown]
# Importar archivos de GIT

# %%
import pandas as pd
#anios = ['2018','2019','2020','2021','2022']
anios = ['2020','2021','2022']
meses = ['01','02','03','04','05','06','07','08','09','10','11','12']

def listado(anios,meses):
  lista=[]
  for a in range(len(anios)):
    for m in range(len(meses)):
      anio=anios[a]
      mes=meses[m]
      print("Comprobando datos de Año : "+str(anios[a])+" Mes : "+str(meses[m]))
      try :
        url = 'https://raw.githubusercontent.com/pcastelli-cba/dnrpa-robos-recuperos-autos/main/dnrpa-robos-recuperos-autos-'+str(anio)+str(mes)+'.csv'
        df = pd.read_csv(url, index_col=0)
        lista.append(url)
      except : 
        print("Datos inexistentes para el Año : "+str(anios[a])+" Mes : "+str(meses[m]))
        break
  return lista

dataFrame = pd.concat(map(pd.read_csv, listado(anios,meses)), ignore_index=True)
print(dataFrame)

dataFrame.to_csv('archivo unificado.csv')
# Out:
# Comprobando datos de Año : 2020 Mes : 01
# Comprobando datos de Año : 2020 Mes : 02
# Comprobando datos de Año : 2020 Mes : 03
# Comprobando datos de Año : 2020 Mes : 04
# Comprobando datos de Año : 2020 Mes : 05
# Comprobando datos de Año : 2020 Mes : 06
# Comprobando datos de Año : 2020 Mes : 07
# Comprobando datos de Año : 2020 Mes : 08
# Comprobando datos de Año : 2020 Mes : 09
# Comprobando datos de Año : 2020 Mes : 10
# Comprobando datos de Año : 2020 Mes : 11
# Comprobando datos de Año : 2020 Mes : 12
# Comprobando datos de Año : 2021 Mes : 01
# Comprobando datos de Año : 2021 Mes : 02
# Comprobando datos de Año : 2021 Mes : 03
# Comprobando datos de Año : 2021 Mes : 04
# Comprobando datos de Año : 2021 Mes : 05
# Comprobando datos de Año : 2021 Mes : 06
# Comprobando datos de Año : 2021 Mes : 07
# Comprobando datos de Año : 2021 Mes : 08
# Comprobando datos de Año : 2021 Mes : 09
# Comprobando datos de Año : 2021 Mes : 10
# Comprobando datos de Año : 2021 Mes : 11
# Comprobando datos de Año : 2021 Mes : 12
# Comprobando datos de Año : 2022 Mes : 01
# Comprobando datos de Año : 2022 Mes : 02
# Comprobando datos de Año : 2022 Mes : 03
# Comprobando datos de Año : 2022 Mes : 04
# Comprobando datos de Año : 2022 Mes : 05
# Comprobando datos de Año : 2022 Mes : 06
# Comprobando datos de Año : 2022 Mes : 07
# Comprobando datos de Año : 2022 Mes : 08
# Comprobando datos de Año : 2022 Mes : 09
# Comprobando datos de Año : 2022 Mes : 10
# Datos inexistentes para el Año : 2022 Mes : 10
#                                         tramite_tipo tramite_fecha  \
# 0      DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2020-01-14
# 1      DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2020-01-10
# 2                           COMUNICACIÓN DE RECUPERO    2020-01-16
# 3      DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2020-01-07
# 4      DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2020-01-17
# ...                                              ...           ...
# 85926  DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2022-09-20
# 85927  DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2022-09-19
# 85928  DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2022-09-08
# 85929  DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2022-09-26
# 85930  DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2022-09-19
#
#       fecha_inscripcion_inicial  registro_seccional_codigo  \
# 0                    1998-08-10                       1001
# 1                    1995-02-07                       1005
# 2                    2006-05-10                       1043
# 3                    1997-05-07                       1046
# 4                    2007-09-26                       1047
# ...                         ...                        ...
# 85926                1997-01-07                       1299
# 85927                1995-01-24                      13020
# 85928                2002-03-15                       1278
# 85929                1995-01-05                       1300
# 85930                1973-12-11                       2066
#
#       registro_seccional_descripcion registro_seccional_provincia  \
# 0                       ADROGUE Nº 1                 Buenos Aires
# 1                    AVELLANEDA Nº 2                 Buenos Aires
# 2                     LA PLATA Nº 01                 Buenos Aires
# 3                     LA PLATA Nº 04                 Buenos Aires
# 4                         LANUS Nº 1                 Buenos Aires
# ...                              ...                          ...
# 85926            MAR DEL PLATA Nº 13                 Buenos Aires
# 85927                  MENDOZA Nº 12                      Mendoza
# 85928                    ZARATE Nº 3                 Buenos Aires
# 85929                SAN MARTIN Nº 9                 Buenos Aires
# 85930         CAPITAL FEDERAL Nº 066    Ciudad Autónoma de Bs.As.
#
#       automotor_origen  automotor_anio_modelo automotor_tipo_codigo  \
# 0             Nacional                 1998.0                   NaN
# 1             Nacional                 1995.0                   NaN
# 2             Nacional                 2006.0                   NaN
# 3             Nacional                 1997.0                   NaN
# 4             Nacional                 2007.0                   NaN
# ...                ...                    ...                   ...
# 85926     Protocolo 21                 1997.0                   NaN
# 85927        Importado                 1995.0                   NaN
# 85928        Importado                 2002.0                   NaN
# 85929        Importado                 1995.0                   NaN
# 85930         Nacional                 1961.0                   NaN
#
#       automotor_tipo_descripcion  ... automotor_uso_descripcion  \
# 0                   RURAL 4 PTAS  ...                   Privado
# 1           FURGON VIDRIADO C/AS  ...                   Privado
# 2            FGON.VID.C/ASIENTOS  ...                   Privado
# 3                    FURGON 3000  ...                   Privado
# 4                     FURGON 600  ...                   Privado
# ...                          ...  ...                       ...
# 85926               SEDAN 5 PTAS  ...                   Privado
# 85927            SEDAN 4 PUERTAS  ...                   Privado
# 85928            RURAL 5 PUERTAS  ...                   Privado
# 85929                      SEDAN  ...                   Privado
# 85930                     CAMION  ...                   Privado
#
#       titular_tipo_persona titular_domicilio_localidad  \
# 0                   Física                     ADROGUE
# 1                   Física              VILLA DOMINICO
# 2                 Jurídica                    LA PLATA
# 3                   Física                    LA PLATA
# 4                   Física                  V.DIAMANTE
# ...                    ...                         ...
# 85926               Física               MAR DEL PLATA
# 85927               Física          GOBERNADOR BENEGAS
# 85928               Física                         NaN
# 85929               Física                     V.MAIPU
# 85930               Física         C.AUTONOMA DE BS.AS
#
#       titular_domicilio_provincia   titular_genero titular_anio_nacimiento  \
# 0                    BUENOS AIRES        Masculino                  1955.0
# 1                    BUENOS AIRES  No identificado                  1964.0
# 2                    BUENOS AIRES        No aplica                  2000.0
# 3                    BUENOS AIRES         Femenino                  1963.0
# 4                    BUENOS AIRES        Masculino                  1957.0
# ...                           ...              ...                     ...
# 85926                BUENOS AIRES         Femenino                  1984.0
# 85927                     MENDOZA        Masculino                  1976.0
# 85928                BUENOS AIRES  No identificado                  1969.0
# 85929                BUENOS AIRES  No identificado                  1993.0
# 85930         C.AUTONOMA DE BS.AS         Femenino                  1979.0
#
#       titular_pais_nacimiento titular_porcentaje_titularidad  \
# 0                   ARGENTINA                            100
# 1                   ARGENTINA                            100
# 2                   No aplica                            100
# 3                   ARGENTINA                            100
# 4                   ARGENTINA                            100
# ...                       ...                            ...
# 85926               ARGENTINA                            100
# 85927               ARGENTINA                            100
# 85928               ARGENTINA                            100
# 85929               ARGENTINA                            100
# 85930               ARGENTINA                            100
#
#       titular_domicilio_provincia_id titular_pais_nacimiento_id
# 0                                6.0                        ARG
# 1                                6.0                        ARG
# 2                                6.0                        NaN
# 3                                6.0                        ARG
# 4                                6.0                        ARG
# ...                              ...                        ...
# 85926                            6.0                        ARG
# 85927                           50.0                        ARG
# 85928                            6.0                        ARG
# 85929                            6.0                        ARG
# 85930                            2.0                        ARG
#
# [85931 rows x 25 columns]

# %%
#Comprobando datos Nan, evidenciamos que la mayor parte de incompletos pertenecen a Nacionalidad del titular ("titular_pais_nacimiento_id")
import missingno as msno
# %matplotlib inline
msno.matrix(dataFrame)

# %%
dataFrame.head()
# Out:
#                                     tramite_tipo tramite_fecha  \
# 0  DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2020-01-14
# 1  DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2020-01-10
# 2                       COMUNICACIÓN DE RECUPERO    2020-01-16
# 3  DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2020-01-07
# 4  DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2020-01-17
#
#   fecha_inscripcion_inicial  registro_seccional_codigo  \
# 0                1998-08-10                       1001
# 1                1995-02-07                       1005
# 2                2006-05-10                       1043
# 3                1997-05-07                       1046
# 4                2007-09-26                       1047
#
#   registro_seccional_descripcion registro_seccional_provincia  \
# 0                   ADROGUE Nº 1                 Buenos Aires
# 1                AVELLANEDA Nº 2                 Buenos Aires
# 2                 LA PLATA Nº 01                 Buenos Aires
# 3                 LA PLATA Nº 04                 Buenos Aires
# 4                     LANUS Nº 1                 Buenos Aires
#
#   automotor_origen  automotor_anio_modelo automotor_tipo_codigo  \
# 0         Nacional                 1998.0                   NaN
# 1         Nacional                 1995.0                   NaN
# 2         Nacional                 2006.0                   NaN
# 3         Nacional                 1997.0                   NaN
# 4         Nacional                 2007.0                   NaN
#
#   automotor_tipo_descripcion  ... titular_tipo_persona  \
# 0               RURAL 4 PTAS  ...               Física
# 1       FURGON VIDRIADO C/AS  ...               Física
# 2        FGON.VID.C/ASIENTOS  ...             Jurídica
# 3                FURGON 3000  ...               Física
# 4                 FURGON 600  ...               Física
#
#   titular_domicilio_localidad titular_domicilio_provincia   titular_genero  \
# 0                     ADROGUE                BUENOS AIRES        Masculino
# 1              VILLA DOMINICO                BUENOS AIRES  No identificado
# 2                    LA PLATA                BUENOS AIRES        No aplica
# 3                    LA PLATA                BUENOS AIRES         Femenino
# 4                  V.DIAMANTE                BUENOS AIRES        Masculino
#
#    titular_anio_nacimiento titular_pais_nacimiento  \
# 0                   1955.0               ARGENTINA
# 1                   1964.0               ARGENTINA
# 2                   2000.0               No aplica
# 3                   1963.0               ARGENTINA
# 4                   1957.0               ARGENTINA
#
#   titular_porcentaje_titularidad titular_domicilio_provincia_id  \
# 0                            100                            6.0
# 1                            100                            6.0
# 2                            100                            6.0
# 3                            100                            6.0
# 4                            100                            6.0
#
#   titular_pais_nacimiento_id   año
# 0                        ARG  2020
# 1                        ARG  2020
# 2                        NaN  2020
# 3                        ARG  2020
# 4                        ARG  2020
#
# [5 rows x 26 columns]

# %%
dataFrame.describe()

# %%
dataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85931 entries, 0 to 85930
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   tramite_tipo                    85931 non-null  object
#  1   tramite_fecha                   85931 non-null  object
#  2   fecha_inscripcion_inicial       85929 non-null  object
#  3   registro_seccional_codigo       85931 non-null  int64
#  4   registro_seccional_descripcion  85931 non-null  object
#  5   registro_seccional_provincia    85931 non-null  object
#  6   automotor_origen                85931 non-null  object
#  7   automotor_anio_modelo           85727 non-null  float64
#  8   automotor_tipo_codigo           83100 non-null  object
#  9   automotor_tipo_descripcion      85931 non-null  object
#  10  automotor_marca_codigo          84728 non-null  object
#  11  automotor_marca_descripcion     85931 non-null  object
#  12  automotor_modelo_codigo         84585 non-null  object
#  13  automotor_modelo_descripcion    85931 non-null  object
#  14  automotor_uso_codigo            85931 non-null  int64
#  15  automotor_uso_descripcion       85931 non-null  object
#  16  titular_tipo_persona            85931 non-null  object
#  17  titular_domicilio_localidad     85836 non-null  object
#  18  titular_domicilio_provincia     85930 non-null  object
#  19  titular_genero                  85931 non-null  object
#  20  titular_anio_nacimiento         85916 non-null  float64
#  21  titular_pais_nacimiento         85931 non-null  object
#  22  titular_porcentaje_titularidad  85931 non-null  int64
#  23  titular_domicilio_provincia_id  85930 non-null  float64
#  24  titular_pais_nacimiento_id      80603 non-null  object
#  25  año                             85931 non-null  object
# dtypes: float64(3), int64(3), object(20)
# memory usage: 17.0+ MB

# %% [markdown]
# Para el dataset recuperos-robos:
#
#   -Determinar modelos mas factibles de robo
#
#   -Marcas con mayor% de robos
#
#   -%de robos por provincias para cada marca
#
#   -evolucion en el tiempo de los % de robos para cada provincia y cada marca

# %%
#importamos librerias para graficar
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# GRAFICAMOS LA CANTIDAD DE AUTOS DENUNCIADOS POR ROBO DISTRIBUIDOS POR MARCA Y A SU VES POR ORIGEN (IMPORTADO, MERCOSUR, NACIONAL)

# %%
dfMsk1=dataFrame['tramite_tipo']=='DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA'
dffiltro=dataFrame[dfMsk1]
sns.countplot(y="automotor_marca_descripcion", hue="automotor_origen", data=dataFrame,
              order=dffiltro.automotor_marca_descripcion.value_counts().iloc[:10].index)

# %%
dffiltro['año']= [x[0:4] for x in dffiltro.tramite_fecha]


sns.displot(data=dffiltro, x="automotor_origen", hue="automotor_origen", col="año")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dffiltro['año']= [x[0:4] for x in dffiltro.tramite_fecha]
dffiltro['año-mes']= [x[0:7] for x in dffiltro.tramite_fecha]
df_origen=dffiltro.groupby(['año-mes','registro_seccional_provincia']).size().iloc[2:1000].reset_index().pivot(columns='registro_seccional_provincia', index='año-mes', values=0)
df_origen
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# registro_seccional_provincia  Buenos Aires  Catamarca  Chaco  Chubut  \
# año-mes
# 2020-01                                NaN        NaN    NaN     NaN
# 2020-02                             1723.0        2.0    4.0     3.0
# 2020-03                             1393.0        NaN    5.0     2.0
# 2020-04                              606.0        2.0    NaN     1.0
# 2020-05                             1247.0        1.0    1.0     4.0
# 2020-06                             1149.0        NaN    3.0     5.0
# 2020-07                             1154.0        NaN    5.0     2.0
# 2020-08                             1230.0        1.0    NaN     6.0
# 2020-09                             1323.0        NaN    2.0     8.0
# 2020-10                             1361.0        2.0    NaN     7.0
# 2020-11                             1405.0        NaN    3.0     4.0
# 2020-12                             1227.0        NaN    2.0     4.0
# 2021-01                             1471.0        NaN    2.0     5.0
# 2021-02                             1481.0        NaN    1.0    12.0
# 2021-03                             1935.0        NaN    1.0    10.0
# 2021-04                             1847.0        NaN    6.0     6.0
# 2021-05                             1405.0        NaN    2.0     5.0
# 2021-06                             1873.0        1.0    NaN     7.0
# 2021-07                             1718.0        1.0    2.0     6.0
# 2021-08                             1859.0        2.0    4.0    10.0
# 2021-09                             2021.0        1.0    3.0     3.0
# 2021-10                             1850.0        2.0    1.0     7.0
# 2021-11                             2159.0        2.0    2.0     7.0
# 2021-12                             1861.0        1.0    4.0     4.0
# 2022-01                             1726.0        NaN    6.0     9.0
# 2022-02                             1780.0        1.0    3.0     4.0
# 2022-03                             2168.0        NaN    4.0     7.0
# 2022-04                             2139.0        1.0    3.0     6.0
# 2022-05                             2191.0        NaN    3.0     3.0
# 2022-06                             2125.0        1.0    7.0     3.0
# 2022-07                             2205.0        2.0    4.0     8.0
# 2022-08                             2139.0        NaN    6.0     6.0
# 2022-09                             1997.0        NaN    5.0     3.0
#
# registro_seccional_provincia  Ciudad Autónoma de Bs.As.  Corrientes  Córdoba  \
# año-mes
# 2020-01                                           420.0        10.0    222.0
# 2020-02                                           361.0         5.0    174.0
# 2020-03                                           251.0         6.0    148.0
# 2020-04                                           105.0         3.0     54.0
# 2020-05                                           197.0         3.0    130.0
# 2020-06                                           215.0         6.0    133.0
# 2020-07                                           212.0        10.0    151.0
# 2020-08                                           240.0         3.0    179.0
# 2020-09                                           301.0         7.0    215.0
# 2020-10                                           270.0         3.0    196.0
# 2020-11                                           298.0         9.0    167.0
# 2020-12                                           291.0         2.0    182.0
# 2021-01                                           300.0         3.0    175.0
# 2021-02                                           268.0         3.0    178.0
# 2021-03                                           357.0         7.0    227.0
# 2021-04                                           343.0         8.0    231.0
# 2021-05                                           266.0         3.0    179.0
# 2021-06                                           364.0        12.0    251.0
# 2021-07                                           350.0         7.0    167.0
# 2021-08                                           346.0         7.0    245.0
# 2021-09                                           399.0        11.0    247.0
# 2021-10                                           335.0         8.0    208.0
# 2021-11                                           429.0        15.0    246.0
# 2021-12                                           383.0         3.0    212.0
# 2022-01                                           320.0         8.0    219.0
# 2022-02                                           341.0         8.0    230.0
# 2022-03                                           364.0         4.0    263.0
# 2022-04                                           345.0         7.0    265.0
# 2022-05                                           395.0         7.0    267.0
# 2022-06                                           356.0         9.0    239.0
# 2022-07                                           421.0        11.0    277.0
# 2022-08                                           420.0         5.0    251.0
# 2022-09                                           390.0        11.0    262.0
#
# registro_seccional_provincia  Entre Ríos  Formosa  Jujuy  ...  Neuquén  \
# año-mes                                                   ...
# 2020-01                             10.0      1.0    1.0  ...     13.0
# 2020-02                             11.0      2.0    3.0  ...     11.0
# 2020-03                              3.0      1.0    1.0  ...      5.0
# 2020-04                              2.0      NaN    2.0  ...      1.0
# 2020-05                              4.0      2.0    NaN  ...      9.0
# 2020-06                              5.0      NaN    2.0  ...      9.0
# 2020-07                              5.0      2.0    NaN  ...     10.0
# 2020-08                              1.0      NaN    1.0  ...      7.0
# 2020-09                              5.0      NaN    NaN  ...     12.0
# 2020-10                              6.0      NaN    4.0  ...     10.0
# 2020-11                              5.0      NaN    2.0  ...     11.0
# 2020-12                              8.0      1.0    NaN  ...     13.0
# 2021-01                              6.0      NaN    1.0  ...     11.0
# 2021-02                              4.0      1.0    1.0  ...     16.0
# 2021-03                              8.0      NaN    2.0  ...     15.0
# 2021-04                              8.0      3.0    3.0  ...     14.0
# 2021-05                              6.0      NaN    1.0  ...      8.0
# 2021-06                              4.0      NaN    2.0  ...     11.0
# 2021-07                              7.0      1.0    NaN  ...     15.0
# 2021-08                              4.0      4.0    3.0  ...     12.0
# 2021-09                              6.0      2.0    3.0  ...     14.0
# 2021-10                             13.0      1.0    3.0  ...     21.0
# 2021-11                             10.0      NaN    2.0  ...     14.0
# 2021-12                              6.0      NaN    2.0  ...     26.0
# 2022-01                              9.0      4.0    4.0  ...     15.0
# 2022-02                             10.0      3.0    5.0  ...     13.0
# 2022-03                              6.0      2.0    1.0  ...     28.0
# 2022-04                              8.0      NaN    NaN  ...     25.0
# 2022-05                             10.0      1.0    5.0  ...     13.0
# 2022-06                              9.0      NaN    7.0  ...     18.0
# 2022-07                             11.0      1.0    2.0  ...     17.0
# 2022-08                              9.0      1.0    4.0  ...     14.0
# 2022-09                             13.0      2.0    2.0  ...     14.0
#
# registro_seccional_provincia  Río Negro  Salta  San Juan  San Luis  \
# año-mes
# 2020-01                            14.0    1.0       1.0       1.0
# 2020-02                             9.0    NaN       4.0       3.0
# 2020-03                             8.0    2.0       1.0       3.0
# 2020-04                             NaN    NaN       NaN       1.0
# 2020-05                             3.0    3.0       1.0       2.0
# 2020-06                             3.0    4.0       NaN       2.0
# 2020-07                             9.0    1.0       1.0       NaN
# 2020-08                             5.0    5.0       NaN       NaN
# 2020-09                             4.0    2.0       NaN       1.0
# 2020-10                             3.0    1.0       NaN       1.0
# 2020-11                             4.0    3.0       1.0       3.0
# 2020-12                             7.0    1.0       2.0       NaN
# 2021-01                             5.0    2.0       2.0       1.0
# 2021-02                            12.0    2.0       NaN       NaN
# 2021-03                             7.0    1.0       NaN       4.0
# 2021-04                             5.0    3.0       1.0       7.0
# 2021-05                             4.0    2.0       1.0       1.0
# 2021-06                             9.0    4.0       1.0       3.0
# 2021-07                             6.0    2.0       1.0       3.0
# 2021-08                             6.0    5.0       1.0       5.0
# 2021-09                            10.0    2.0       2.0       5.0
# 2021-10                             8.0    5.0       4.0       3.0
# 2021-11                            12.0    NaN       4.0       NaN
# 2021-12                            11.0    1.0       NaN       4.0
# 2022-01                            14.0    1.0       4.0       6.0
# 2022-02                            13.0    1.0       1.0       3.0
# 2022-03                            12.0    7.0       1.0       3.0
# 2022-04                            10.0    4.0       NaN       1.0
# 2022-05                             6.0    5.0       4.0       6.0
# 2022-06                            16.0    3.0       4.0       2.0
# 2022-07                            13.0    1.0       1.0      10.0
# 2022-08                            14.0    5.0       6.0       1.0
# 2022-09                            10.0    2.0       NaN       3.0
#
# registro_seccional_provincia  Santa Cruz  Santa Fe  Santiago del Estero  \
# año-mes
# 2020-01                              NaN     112.0                  3.0
# 2020-02                              1.0      67.0                  2.0
# 2020-03                              2.0      78.0                  2.0
# 2020-04                              NaN      26.0                  NaN
# 2020-05                              1.0      66.0                  NaN
# 2020-06                              3.0      75.0                  1.0
# 2020-07                              2.0      74.0                  1.0
# 2020-08                              NaN      93.0                  NaN
# 2020-09                              1.0      94.0                  1.0
# 2020-10                              NaN      76.0                  NaN
# 2020-11                              NaN      83.0                  1.0
# 2020-12                              2.0      74.0                  4.0
# 2021-01                              2.0      85.0                  1.0
# 2021-02                              NaN      75.0                  1.0
# 2021-03                              2.0     108.0                  1.0
# 2021-04                              3.0      87.0                  1.0
# 2021-05                              NaN      76.0                  1.0
# 2021-06                              1.0     105.0                  3.0
# 2021-07                              NaN      98.0                  2.0
# 2021-08                              5.0     101.0                  4.0
# 2021-09                              5.0     129.0                  3.0
# 2021-10                              1.0     113.0                  3.0
# 2021-11                              2.0     138.0                  2.0
# 2021-12                              5.0     106.0                  1.0
# 2022-01                              3.0     107.0                  1.0
# 2022-02                              3.0     130.0                  3.0
# 2022-03                              2.0     134.0                  1.0
# 2022-04                              2.0     121.0                  1.0
# 2022-05                              1.0     158.0                  5.0
# 2022-06                              3.0     163.0                  3.0
# 2022-07                              2.0     152.0                  NaN
# 2022-08                              1.0     146.0                  4.0
# 2022-09                              2.0     143.0                  2.0
#
# registro_seccional_provincia  Tierra del Fuego  Tucumán
# año-mes
# 2020-01                                    1.0      3.0
# 2020-02                                    NaN      5.0
# 2020-03                                    1.0      1.0
# 2020-04                                    NaN      1.0
# 2020-05                                    NaN      5.0
# 2020-06                                    NaN      1.0
# 2020-07                                    2.0      1.0
# 2020-08                                    NaN      1.0
# 2020-09                                    1.0      2.0
# 2020-10                                    1.0      5.0
# 2020-11                                    1.0      4.0
# 2020-12                                    NaN      2.0
# 2021-01                                    1.0      4.0
# 2021-02                                    1.0      2.0
# 2021-03                                    1.0      3.0
# 2021-04                                    3.0      8.0
# 2021-05                                    1.0      1.0
# 2021-06                                    2.0      3.0
# 2021-07                                    3.0      6.0
# 2021-08                                    3.0      7.0
# 2021-09                                    1.0      4.0
# 2021-10                                    2.0      5.0
# 2021-11                                    3.0      9.0
# 2021-12                                    NaN      7.0
# 2022-01                                    4.0      7.0
# 2022-02                                    2.0      5.0
# 2022-03                                    4.0      9.0
# 2022-04                                    1.0      9.0
# 2022-05                                    3.0      3.0
# 2022-06                                    1.0      8.0
# 2022-07                                    5.0      8.0
# 2022-08                                    2.0      3.0
# 2022-09                                    2.0      3.0
#
# [33 rows x 24 columns]

# %%
df_origen.plot(stacked=True)

# %%
dataFrame['automotor_marca_descripcion'].value_counts().iloc[0:50].plot(kind='bar', figsize=(12,6), ylabel='Frecuencia', title='Marcas mas robadas')

# %%
dataFrame['automotor_modelo_descripcion'].value_counts().iloc[0:50].plot(kind='bar', figsize=(12,6), ylabel='Frecuencia', title='Modelos mas robadas')

# %%
dataFrame['titular_genero'].value_counts().plot(kind='bar', figsize=(12,6), ylabel='Frecuencia', title='Robos por genero')

# %%
dataFrame['titular_domicilio_provincia'].value_counts().plot(kind='bar', figsize=(12,6), ylabel='Frecuencia', title='Procedencia del titular')
